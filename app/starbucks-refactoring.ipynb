# %%
# parser 필요한 모듈 (selenium, bs4)
from selenium import webdriver
from bs4 import BeautifulSoup

# url 이미지 다운
import urllib.request

driver = webdriver.Chrome('/Users/han-yonghee/projects/coffeecalorie/.tool/chromedriver')

# 스타벅스 음료 페이지 [전체 상품보기]
driver.get('http://www.istarbucks.co.kr/menu/drink_list.do')
html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

# %%
dt_category = soup.select('dl.product_view_tab > dd > div.product_list > dl > dt > a')
dd_content = soup.select('dl.product_view_tab > dd > div.product_list > dl > dd')
print(len(dd_content))
# Out:
# 10

# %%
for a, b in zip(dt_category, dd_content):
    # 카테고리 타이틀 
    category_title = a.get_text(strip=True)
#     print(category_title)
#     print('====끝====')
    # 커피 이름 & 이미지 URL & 커피 디테일 URL
    coffee_name_image_list = b.select('ul > li.menuDataSet')
    for name_image in coffee_name_image_list:
        coffee_name = name_image.select_one('dl > dd').get_text()
#         print(coffee_name)
        coffee_image_url = name_image.select_one('dl > dt > a > img')
        coffee_image = coffee_image_url.get('src')
#         print(coffee_image)
#         urllib.request.urlretrieve(coffee_image, f'{coffee_name}.jpg')
        coffee_url_total = name_image.select_one('dl > dt > a')
        coffee_url = coffee_url_total.get('prod')
        coffee_base_url = 'http://www.istarbucks.co.kr/menu/drink_view.do?product_cd='
        
        # 커피 디테일 페이지 접근
        driver.get(coffee_base_url + coffee_url)
        driver.implicitly_wait(7)
        html = driver.page_source
        soup = BeautifulSoup(html, 'lxml')
        pages_detail = soup.select('div.content02 > div.product_view_wrap1 > div.product_view_detail')
        pages_detail2 = soup.select('form > fieldset > div.product_view_info > div.product_info_content')
        for detail in pages_detail:
            # 커피 detail name
            detail_names = detail.select_one('div.myAssignZone > h4').get_text(strip=True)
            print(detail_names)
            # 커피 detail info
            detail_infos = detail.select_one('div.myAssignZone > p').get_text(strip=True)
            print(detail_infos)
            # 커피 detail 제품영양정보 단위
            detail_sizes = detail.select_one('form > fieldset > div.product_view_info > div.product_info_head > div.product_select_wrap2 > div.selectTxt2').get_text(strip=True)
            print(detail_sizes)
        for detail2 in pages_detail2:
            # 커피 detail kcal
            detail_kcal = detail2.select_one('ul > li.kcal > dl > dd').get_text(strip=True)
            print(detail_kcal)
            # 커피 detail sat_FAT
            detail_fats = detail2.select_one('ul > li.sat_FAT > dl > dd').get_text(strip=True)
            print(detail_fats)
            # 커피 detail protein
            detail_proteins = detail2.select_one('ul > li.protein > dl > dd').get_text(strip=True)
            print(detail_proteins)
            # 커피 detail sodium
            detail_sodiums = detail2.select_one('ul:nth-of-type(2) > li.sodium > dl > dd').get_text(strip=True)
            print(detail_sodiums)
            # 커피 detail sugar
            detail_sugars = detail2.select_one('ul:nth-of-type(2) > li.sugars > dl > dd').get_text(strip=True)
            print(detail_sugars)
            # 커피 detail caffeine
            detail_caffeines = detail2.select_one('ul:nth-of-type(2) > li.caffeine > dl > dd').get_text(strip=True)
            print(detail_caffeines)
            print('==== 커피 끝 ====')
            
        # DB 작업
        CoffeeCategory.objects.get_or_create(
            name=category_title
        )
        Coffee.objects.get_or_create(
            coffeeshop_list='STARBUCKS',
            category=CoffeeCategory.objects.get(name=category_title),
            name=detail_names,
            coffee_info=detail_infos,
            coffee_size=detail_sizes,
            calorie=detail_kcal,
            saturated_fat=detail_fats,
            protein=detail_proteins,
            sodium=detail_sodiums,
            sugars=detail_sugars,
            caffeine=detail_caffeines,
        )
# Out:
# 나이트로 쇼콜라Nitro Chocolat
# 초콜릿과 견과류의 풍미, 초콜릿 파우더 토핑, 풀 바디감의 새로운 나이트로 콜드 브루
# Tall(톨) / 355ml (12 fl oz)
# 30
# 0
# 0
# 10
# 6
# 245
# ==== 커피 끝 ====
# 나이트로 쇼콜라 클라우드Nitro Chocolat Cloud
# 초콜릿과 견과류의 풍미, 초콜릿 파우더 토핑, 하프&하프 샷부드럽고 달콤한 새로운 나이트로 콜드 브루
# Tall(톨) / 355ml (12 fl oz)
# 55
# 2
# 1
# 20
# 7
# 245
# ==== 커피 끝 ====
# 나이트로 콜드 브루Nitro Cold Brew
# 나이트로 커피 정통의 캐스케이딩과 부드러운 콜드 크레마!부드러운 목 넘김과 완벽한 밸런스에 커피 본연의 단맛을 경험할 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 5
# 0
# 0
# 5
# 0
# 245
# ==== 커피 끝 ====
# 바닐라 크림 콜드 브루Vanilla Cream Cold Brew
# 콜드 브루에 더해진 바닐라 크림으로 깔끔하면서 달콤한 콜드 브루를 새롭게 즐길 수 있는 음료입니다.
# Tall(톨) / 355ml (12 fl oz)
# 125
# 6
# 3
# 58
# 11
# 150
# ==== 커피 끝 ====
# 콜드 브루Cold Brew
# 스타벅스 바리스타의 정성으로 탄생한 콜드 브루!콜드 브루 전용 원두를 차가운 물로 14시간 동안 추출하여 한정된 양만 제공됩니다.깊은 풍미의 새로운 커피 경험을 즐겨보세요.
# Tall(톨) / 355ml (12 fl oz)
# 5
# 0
# 0
# 11
# 0
# 150
# ==== 커피 끝 ====
# 콜드 브루 몰트Cold Brew Malt
# [리저브 전용음료] 리저브 콜드 브루, 바닐라 아이스크림, 몰트가 블렌딩된 리저브만의 쉐이크
# Tall(톨) / 355ml (12 fl oz)
# 510
# 20
# 10
# 147.8
# 40
# 150
# ==== 커피 끝 ====
# 콜드 브루 플로트Cold Brew Float
# [리저브 전용음료] 리저브 콜드 브루 위에 녹아 내리는 한 스쿱의 바닐라 아이스크림
# Tall(톨) / 355ml (12 fl oz)
# 230
# 10
# 3
# 69
# 18
# 150
# ==== 커피 끝 ====
# 콜드 폼 콜드 브루Cold Foam Cold Brew
# 부드럽고 쫀득하며 달콤한 콜드 폼을 즐기고 콜드 브루를 같이 마시면 더욱 부드러운 목넘김을 즐길 수 있는 음료 입니다.
# Tall(톨) / 355ml (12 fl oz)
# 105
# 0
# 5
# 175
# 20
# 150
# ==== 커피 끝 ====
# 아이스 커피Iced Coffee
# 깔끔하고 상큼함이 특징인 시원한 아이스 커피
# Tall(톨) / 355ml (12 fl oz)
# 5
# 0
# 0
# 10
# 0
# 140
# ==== 커피 끝 ====
# 오늘의 커피Brewed Coffee
# 신선하게 브루드(Brewed)되어 원두의 다양함이 살아있는 커피
# Tall(톨) / 355ml (12 fl oz)
# 5
# 0
# 0
# 10
# 0
# 260
# ==== 커피 끝 ====
# 슈 크림 크런치 라떼Choux Cream Crunch Latte
# 새롭게 돌아온 슈 크림 크런치 라떼!바삭한 슈크런치 토핑이 올라가 진짜 슈 크림 빵을 먹는 느낌을 구현한 새로운 슈 크림 크런치 라떼!
# Tall(톨) / 355ml (12 fl oz)
# 330
# 11
# 9
# 180
# 33
# 63
# ==== 커피 끝 ====
# 아이스 슈 크림 크런치 라떼Iced Choux Cream Crunch Latte
# 새롭게 돌아온 슈 크림 크런치 라떼!바삭한 슈크런치 토핑이 올라가 진짜 슈 크림 빵을 먹는 느낌을 구현한 새로운 슈 크림 크런치 라떼!
# Tall(톨) / 355ml (12 fl oz)
# 275
# 9
# 6
# 130
# 28
# 63
# ==== 커피 끝 ====
# 아이스 헤이즐넛 더블 마키아또Iced Hazelnut Double Macchiato
# 정통 마키아또를 더욱 진하고 색다르게 즐길 수 있는 음료! 에스프레소 투샷의 진한 맛에 헤이즐넛 시럽과 드리즐을 더하고 카라멜 아몬드 토핑까지!마지막은 바리스타의 핸드크래프트 에칭 아트로 마무리한 음료!
# Tall(톨) / 355ml (12 fl oz)
# 240
# 7
# 8
# 115
# 24
# 125
# ==== 커피 끝 ====
# 헤이즐넛 더블 마키아또Hazelnut Double Macchiato
# 정통 마키아또를 더욱 진하고 색다르게 즐길 수 있는 음료! 에스프레소 투샷의 진한 맛에 헤이즐넛 시럽과 드리즐을 더하고 카라멜 아몬드 토핑까지!마지막은 바리스타의 핸드크래프트 에칭 아트로 마무리한 음료!
# Tall(톨) / 355ml (12 fl oz)
# 290
# 7
# 12
# 180
# 30
# 125
# ==== 커피 끝 ====
# 에스프레소 콘 파나Espresso Con Panna
# 에스프레소 샷에 풍부한 휘핑크림을 얹은 강렬하고 달콤한 음료
# Solo(솔로) / 22ml (0.75 fl oz)
# 30
# 1.5
# 0
# 0
# 1
# 75
# ==== 커피 끝 ====
# 에스프레소 마키아또Espresso Macchiato
# 강렬한 에스프레소 위에 소량의 우유 거품이 얹어진 음료
# Solo(솔로) / 22ml (0.75 fl oz)
# 10
# 0
# 1
# 0
# 0
# 75
# ==== 커피 끝 ====
# 아이스 카페 아메리카노Iced Caffe Americano
# 강렬한 에스프레소 샷에 시원한 물의 조화
# Tall(톨) / 355ml (12 fl oz)
# 10
# 0
# 1
# 5
# 0
# 150
# ==== 커피 끝 ====
# 카페 아메리카노Caffe Americano
# 강렬한 에스프레소 샷에 뜨거운 물의 조화
# Tall(톨) / 355ml (12 fl oz)
# 10
# 0
# 1
# 5
# 0
# 150
# ==== 커피 끝 ====
# 아이스 카라멜 마키아또Iced Caramel Macchiato
# 바닐라 시럽, 시원한 우유에 얼음과 에스프레소 샷, 카라멜 드리즐이 어우러진 음료
# Tall(톨) / 355ml (12 fl oz)
# 190
# 4.5
# 7
# 95
# 22
# 75
# ==== 커피 끝 ====
# 카라멜 마키아또Caramel Macchiato
# 바닐라 시럽과 우유, 그리고 그 위에 얹어진 에스프레소 샷과 달콤한 카라멜 드리즐의 조화
# Tall(톨) / 355ml (12 fl oz)
# 200
# 4.5
# 8
# 100
# 22
# 75
# ==== 커피 끝 ====
# 아이스 카푸치노Iced Cappuccino
# 에스프레소 샷과 시원한 우유에 부드러운 우유 거품이 얹어진 시원한 음료.
# Tall(톨) / 355ml (12 fl oz)
# 115
# 3.5
# 6
# 90
# 9
# 75
# ==== 커피 끝 ====
# 카푸치노Cappuccino
# 벨벳같은 우유 거품과 에스프레소 샷의 절묘한 조화!
# Tall(톨) / 355ml (12 fl oz)
# 110
# 3
# 6
# 70
# 8
# 75
# ==== 커피 끝 ====
# 콜드 폼 카푸치노Cold Foam Cappuccino
# 카푸치노 특유의 풍성한 폼을 플레인 콜드 폼으로 표현하였으며, 추로스 슈거 토핑으로 비쥬얼적으로 새로움을 전합니다.
# Tall(톨) / 355ml (12 fl oz)
# 155
# 2
# 5
# 138
# 20
# 150
# ==== 커피 끝 ====
# 라벤더 카페 브레베Lavender Cafe Breve
# [더종로R,청담스타R,한강진역R,홍대입구역사거리R 전용음료] 블랙이글로 추출한 리저브 에스프레소 샷과 은은한 라벤더향이 고급스럽게 어우러진 리저브 특화음료입니다.
# Tall(톨) / 355ml (12 fl oz)
# 406
# 22
# 7
# 140
# 30
# 75
# ==== 커피 끝 ====
# 럼 샷 코르타도Rum Shot Cortado
# [더종로R,청담스타R,한강진역R,홍대입구역사거리R 전용음료] 최고의 리저브 에스프레소 샷, 스팀 밀크 그리고 럼이 짙게 어우러진 스타벅스 리저브 만의 코르타도입니다.
# Short(숏) / 237ml (8 fl oz)
# 70
# 1.8
# 3
# 45
# 8
# 75
# ==== 커피 끝 ====
# 스타벅스 돌체 라떼Starbucks Dolce Latte
# 깊은 에스프레소와 깔끔한 무지방 우유가 어우러진 달콤한 음료.
# Tall(톨) / 355ml (12 fl oz)
# 255
# 2.5
# 12
# 190
# 39
# 150
# ==== 커피 끝 ====
# 아이스 라벤더 카페 브레베Iced Lavender Cafe Breve
# [더종로R,청담스타R,한강진역R,홍대입구역사거리R 전용음료] 블랙이글로 추출한 리저브 에스프레소 샷과 은은한 라벤더향이 고급스럽게 어우러진 리저브 특화음료입니다.
# Tall(톨) / 355ml (12 fl oz)
# 335
# 18
# 6
# 110
# 27
# 75
# ==== 커피 끝 ====
# 아이스 스타벅스 돌체 라떼Iced Starbucks Dolce Latte
# 커피 향과 부드러움의 조화가 아주 멋진 아이스 커피 입니다.
# Tall(톨) / 355ml (12 fl oz)
# 230
# 2.5
# 10
# 145
# 35
# 150
# ==== 커피 끝 ====
# 아이스 카페 라떼Iced Caffe Latte
# 에스프레소 샷과 시원한 우유와 얼음으로 고소한 음료.
# Tall(톨) / 355ml (12 fl oz)
# 110
# 3.5
# 6
# 75
# 8
# 75
# ==== 커피 끝 ====
# 카페 라떼Caffe Latte
# 에스프레소 샷과 따뜻한 우유와 거품으로 마무리된 음료.
# Tall(톨) / 355ml (12 fl oz)
# 180
# 5
# 10
# 115
# 13
# 75
# ==== 커피 끝 ====
# 아이스 카페 모카Iced Caffe Mocha
# 모카시럽과 시원한 우유에 휘핑크림이 토핑된 에스프레소 음료.
# Tall(톨) / 355ml (12 fl oz)
# 250
# 8
# 7
# 70
# 21
# 95
# ==== 커피 끝 ====
# 아이스 화이트 초콜릿 모카Iced White Chocolate Mocha
# 화이트 초콜릿과 시원한 우유가 첨가된 에스프레소 음료.
# Tall(톨) / 355ml (12 fl oz)
# 350
# 11
# 8
# 150
# 41
# 75
# ==== 커피 끝 ====
# 카페 모카Caffe Mocha
# 모카시럽과 스팀밀크에 휘핑크림이 토핑된 에스프레소.
# Tall(톨) / 355ml (12 fl oz)
# 290
# 9
# 10
# 105
# 25
# 95
# ==== 커피 끝 ====
#
#
#
#
#
#
#
#
#
# ==== 커피 끝 ====
# ---------------------------------------------------------------------------
# InvalidOperation                          Traceback (most recent call last)
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/django/db/models/fields/__init__.py in to_python(self, value)
#    1553         try:
# -> 1554             return decimal.Decimal(value)
#    1555         except decimal.InvalidOperation:
#
# InvalidOperation: [<class 'decimal.ConversionSyntax'>]
#
# During handling of the above exception, another exception occurred:
#
# ValidationError                           Traceback (most recent call last)
# <ipython-input-3-c03f963921ba> in <module>
#      70             sodium=detail_sodiums,
#      71             sugars=detail_sugars,
# ---> 72             caffeine=detail_caffeines,
#      73         )
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      80         def create_method(name, method):
#      81             def manager_method(self, *args, **kwargs):
# ---> 82                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      83             manager_method.__name__ = method.__name__
#      84             manager_method.__doc__ = method.__doc__
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/django/db/models/query.py in get_or_create(self, defaults, **kwargs)
#     484         self._for_write = True
#     485         try:
# --> 486             return self.get(**lookup), False
#     487         except self.model.DoesNotExist:
#     488             return self._create_object_from_params(lookup, params)
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/django/db/models/query.py in get(self, *args, **kwargs)
#     388         keyword arguments.
#     389         """
# --> 390         clone = self.filter(*args, **kwargs)
#     391         if self.query.can_filter() and not self.query.distinct_fields:
#     392             clone = clone.order_by()
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/django/db/models/query.py in filter(self, *args, **kwargs)
#     842         set.
#     843         """
# --> 844         return self._filter_or_exclude(False, *args, **kwargs)
#     845
#     846     def exclude(self, *args, **kwargs):
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/django/db/models/query.py in _filter_or_exclude(self, negate, *args, **kwargs)
#     860             clone.query.add_q(~Q(*args, **kwargs))
#     861         else:
# --> 862             clone.query.add_q(Q(*args, **kwargs))
#     863         return clone
#     864
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/django/db/models/sql/query.py in add_q(self, q_object)
#    1261         # So, demotion is OK.
#    1262         existing_inner = {a for a in self.alias_map if self.alias_map[a].join_type == INNER}
# -> 1263         clause, _ = self._add_q(q_object, self.used_aliases)
#    1264         if clause:
#    1265             self.where.add(clause, AND)
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/django/db/models/sql/query.py in _add_q(self, q_object, used_aliases, branch_negated, current_negated, allow_joins, split_subq)
#    1285                     child, can_reuse=used_aliases, branch_negated=branch_negated,
#    1286                     current_negated=current_negated, allow_joins=allow_joins,
# -> 1287                     split_subq=split_subq,
#    1288                 )
#    1289                 joinpromoter.add_votes(needed_inner)
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/django/db/models/sql/query.py in build_filter(self, filter_expr, branch_negated, current_negated, can_reuse, allow_joins, split_subq, reuse_with_filtered_relation)
#    1223             col = targets[0].get_col(alias, join_info.final_field)
#    1224
# -> 1225         condition = self.build_lookup(lookups, col, value)
#    1226         lookup_type = condition.lookup_name
#    1227         clause.add(condition, AND)
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/django/db/models/sql/query.py in build_lookup(self, lookups, lhs, rhs)
#    1094                 return
#    1095
# -> 1096         lookup = lookup_class(lhs, rhs)
#    1097         # Interpret '__exact=None' as the sql 'is NULL'; otherwise, reject all
#    1098         # uses of None as a query value unless the lookup supports it.
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/django/db/models/lookups.py in __init__(self, lhs, rhs)
#      18     def __init__(self, lhs, rhs):
#      19         self.lhs, self.rhs = lhs, rhs
# ---> 20         self.rhs = self.get_prep_lookup()
#      21         if hasattr(self.lhs, 'get_bilateral_transforms'):
#      22             bilateral_transforms = self.lhs.get_bilateral_transforms()
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/django/db/models/lookups.py in get_prep_lookup(self)
#      68             return self.rhs._prepare(self.lhs.output_field)
#      69         if self.prepare_rhs and hasattr(self.lhs.output_field, 'get_prep_value'):
# ---> 70             return self.lhs.output_field.get_prep_value(self.rhs)
#      71         return self.rhs
#      72
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/django/db/models/fields/__init__.py in get_prep_value(self, value)
#    1565     def get_prep_value(self, value):
#    1566         value = super().get_prep_value(value)
# -> 1567         return self.to_python(value)
#    1568
#    1569     def formfield(self, **kwargs):
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/django/db/models/fields/__init__.py in to_python(self, value)
#    1557                 self.error_messages['invalid'],
#    1558                 code='invalid',
# -> 1559                 params={'value': value},
#    1560             )
#    1561
#
# ValidationError: ["'' 값은 10진수를 입력하여야 합니다."]

# %%
print(type(float_detail_fats))

# %%
a =3
