# %%
# parser 필요한 모듈 (selenium, bs4)
from selenium import webdriver
from bs4 import BeautifulSoup

# url 이미지 다운
import urllib.request

driver = webdriver.Chrome('/Users/han-yonghee/projects/coffeecalorie/.tool/chromedriver')

# 스타벅스 음료 페이지 [전체 상품보기]
driver.get('http://www.istarbucks.co.kr/menu/drink_list.do')
html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

# %%
dt_category = soup.select('dl.product_view_tab > dd > div.product_list > dl > dt > a')
dd_content = soup.select('dl.product_view_tab > dd > div.product_list > dl > dd')
print(len(dd_content))
# Out:
# 10

# %%
# for a, b in zip(dt_category, dd_content):
#     # 카테고리 타이틀 
#     category_title = a.get_text(strip=True)
# #     print(category_title)
# #     print('====끝====')
#     # 커피 이름 & 이미지 URL & 커피 디테일 URL
#     coffee_name_image_list = b.select('ul > li.menuDataSet')
#     for name_image in coffee_name_image_list:
#         coffee_name = name_image.select_one('dl > dd').get_text()
# #         print(coffee_name)
#         coffee_image_url = name_image.select_one('dl > dt > a > img')
#         coffee_image = coffee_image_url.get('src')
# #         print(coffee_image)
# #         urllib.request.urlretrieve(coffee_image, f'{coffee_name}.jpg')
#         coffee_url_total = name_image.select_one('dl > dt > a')
#         coffee_url = coffee_url_total.get('prod')
#         coffee_base_url = 'http://www.istarbucks.co.kr/menu/drink_view.do?product_cd='

#         # 커피 디테일 페이지 접근
#         driver.get(coffee_base_url + coffee_url)
#         driver.implicitly_wait(7)
#         html = driver.page_source
#         soup = BeautifulSoup(html, 'lxml')
#         pages_detail = soup.select('div.content02 > div.product_view_wrap1 > div.product_view_detail')
#         pages_detail2 = soup.select('form > fieldset > div.product_view_info > div.product_info_content')
#         for detail in pages_detail:
#             # 커피 detail name
#             detail_names = detail.select_one('div.myAssignZone > h4').get_text(strip=True)
#             print(detail_names)
#             # 커피 detail info
#             detail_infos = detail.select_one('div.myAssignZone > p').get_text(strip=True)
#             print(detail_infos)
#             # 커피 detail 제품영양정보 단위
#             detail_sizes = detail.select_one('form > fieldset > div.product_view_info > div.product_info_head > div.product_select_wrap2 > div.selectTxt2').get_text(strip=True)
#             print(detail_sizes)
#         for detail2 in pages_detail2:
#             # 커피 detail kcal
#             detail_kcal = detail2.select_one('ul > li.kcal > dl > dd').get_text(strip=True)
#             print(detail_kcal)
#             # 커피 detail sat_FAT
#             detail_fats = detail2.select_one('ul > li.sat_FAT > dl > dd').get_text(strip=True)
#             print(detail_fats)
#             # 커피 detail protein
#             detail_proteins = detail2.select_one('ul > li.protein > dl > dd').get_text(strip=True)
#             print(detail_proteins)
#             # 커피 detail sodium
#             detail_sodiums = detail2.select_one('ul:nth-of-type(2) > li.sodium > dl > dd').get_text(strip=True)
#             print(detail_sodiums)
#             # 커피 detail sugar
#             detail_sugars = detail2.select_one('ul:nth-of-type(2) > li.sugars > dl > dd').get_text(strip=True)
#             print(detail_sugars)
#             # 커피 detail caffeine
#             detail_caffeines = detail2.select_one('ul:nth-of-type(2) > li.caffeine > dl > dd').get_text(strip=True)
#             print(detail_caffeines)
#             print('==== 커피 끝 ====')

#         # DB 작업
#         CoffeeCategory.objects.get_or_create(
#             name=category_title
#         )
#         Coffee.objects.get_or_create(
#             coffeeshop_list='STARBUCKS',
#             category=CoffeeCategory.objects.get(name=category_title),
#             name=detail_names,
#             coffee_info=detail_infos,
#             coffee_size=detail_sizes,
#             calorie=detail_kcal,
#             saturated_fat=detail_fats,
#             protein=detail_proteins,
#             sodium=detail_sodiums,
#             sugars=detail_sugars,
#             caffeine=detail_caffeines,
#         )

# %% [markdown]
# ## 팝업 에러 해결중 [완료]

# %%
for a, b in zip(dt_category, dd_content):
    # 카테고리 타이틀 
    category_title = a.get_text(strip=True)
#     print(category_title)
#     print('====끝====')
    # 커피 이름 & 이미지 URL & 커피 디테일 URL
    coffee_name_image_list = b.select('ul > li.menuDataSet')
    for name_image in coffee_name_image_list:
        coffee_name = name_image.select_one('dl > dd').get_text()
        if '아이스 제주 유자 그린 티' in coffee_name:
            continue
        elif '애프리콧 조이풀 티' in coffee_name:
            continue
        elif '제주 유자 그린 티' in coffee_name:
            continue
        elif '아이스 제주 한라봉 눈꽃 라떼' in coffee_name:
            continue
        elif '제주 한라봉 눈꽃 라떼' in coffee_name:
            continue
        else:
            pass
#         print(coffee_name)
        coffee_image_url = name_image.select_one('dl > dt > a > img')
        coffee_image = coffee_image_url.get('src')
#         print(coffee_image)
#         urllib.request.urlretrieve(coffee_image, f'{coffee_name}.jpg')
        coffee_url_total = name_image.select_one('dl > dt > a')
        coffee_url = coffee_url_total.get('prod')
        coffee_base_url = 'http://www.istarbucks.co.kr/menu/drink_view.do?product_cd='

        # 커피 디테일 페이지 접근
        driver.get(coffee_base_url + coffee_url)
        driver.implicitly_wait(7)
        html = driver.page_source
        soup = BeautifulSoup(html, 'lxml')
        pages_detail = soup.select('div.content02 > div.product_view_wrap1 > div.product_view_detail')
        pages_detail2 = soup.select('form > fieldset > div.product_view_info > div.product_info_content')
        for detail in pages_detail:
            # 커피 detail name
            detail_names = detail.select_one('div.myAssignZone > h4').get_text(strip=True)
            print(detail_names)
            # 커피 detail info
            detail_infos = detail.select_one('div.myAssignZone > p').get_text(strip=True)
            print(detail_infos)
            # 커피 detail 제품영양정보 단위
            detail_sizes = detail.select_one('form > fieldset > div.product_view_info > div.product_info_head > div.product_select_wrap2 > div.selectTxt2').get_text(strip=True)
            print(detail_sizes)
        for detail2 in pages_detail2:
            # 커피 detail kcal
            detail_kcal = detail2.select_one('ul > li.kcal > dl > dd').get_text(strip=True)
            print(detail_kcal)
            # 커피 detail sat_FAT
            detail_fats = detail2.select_one('ul > li.sat_FAT > dl > dd').get_text(strip=True)
            print(detail_fats)
            # 커피 detail protein
            detail_proteins = detail2.select_one('ul > li.protein > dl > dd').get_text(strip=True)
            print(detail_proteins)
            # 커피 detail sodium
            detail_sodiums = detail2.select_one('ul:nth-of-type(2) > li.sodium > dl > dd').get_text(strip=True)
            print(detail_sodiums)
            # 커피 detail sugar
            detail_sugars = detail2.select_one('ul:nth-of-type(2) > li.sugars > dl > dd').get_text(strip=True)
            print(detail_sugars)
            # 커피 detail caffeine
            detail_caffeines = detail2.select_one('ul:nth-of-type(2) > li.caffeine > dl > dd').get_text(strip=True)
            print(detail_caffeines)
            print('==== 커피 끝 ====')

        # DB 작업
        CoffeeCategory.objects.get_or_create(
            name=category_title
        )
        Coffee.objects.get_or_create(
            coffeeshop_list='STARBUCKS',
            category=CoffeeCategory.objects.get(name=category_title),
            name=detail_names,
            coffee_info=detail_infos,
            coffee_size=detail_sizes,
            calorie=detail_kcal,
            saturated_fat=detail_fats,
            protein=detail_proteins,
            sodium=detail_sodiums,
            sugars=detail_sugars,
            caffeine=detail_caffeines,
        )
driver.close()
# Out:
# 나이트로 쇼콜라Nitro Chocolat
# 초콜릿과 견과류의 풍미, 초콜릿 파우더 토핑, 풀 바디감의 새로운 나이트로 콜드 브루
# Tall(톨) / 355ml (12 fl oz)
# 30
# 0
# 0
# 10
# 6
# 245
# ==== 커피 끝 ====
# 나이트로 쇼콜라 클라우드Nitro Chocolat Cloud
# 초콜릿과 견과류의 풍미, 초콜릿 파우더 토핑, 하프&하프 샷부드럽고 달콤한 새로운 나이트로 콜드 브루
# Tall(톨) / 355ml (12 fl oz)
# 55
# 2
# 1
# 20
# 7
# 245
# ==== 커피 끝 ====
# 나이트로 콜드 브루Nitro Cold Brew
# 나이트로 커피 정통의 캐스케이딩과 부드러운 콜드 크레마!부드러운 목 넘김과 완벽한 밸런스에 커피 본연의 단맛을 경험할 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 5
# 0
# 0
# 5
# 0
# 245
# ==== 커피 끝 ====
# 바닐라 크림 콜드 브루Vanilla Cream Cold Brew
# 콜드 브루에 더해진 바닐라 크림으로 깔끔하면서 달콤한 콜드 브루를 새롭게 즐길 수 있는 음료입니다.
# Tall(톨) / 355ml (12 fl oz)
# 125
# 6
# 3
# 58
# 11
# 150
# ==== 커피 끝 ====
# 콜드 브루Cold Brew
# 스타벅스 바리스타의 정성으로 탄생한 콜드 브루!콜드 브루 전용 원두를 차가운 물로 14시간 동안 추출하여 한정된 양만 제공됩니다.깊은 풍미의 새로운 커피 경험을 즐겨보세요.
# Tall(톨) / 355ml (12 fl oz)
# 5
# 0
# 0
# 11
# 0
# 150
# ==== 커피 끝 ====
# 콜드 브루 몰트Cold Brew Malt
# [리저브 전용음료] 리저브 콜드 브루, 바닐라 아이스크림, 몰트가 블렌딩된 리저브만의 쉐이크
# Tall(톨) / 355ml (12 fl oz)
# 510
# 20
# 10
# 147.8
# 40
# 150
# ==== 커피 끝 ====
# 콜드 브루 플로트Cold Brew Float
# [리저브 전용음료] 리저브 콜드 브루 위에 녹아 내리는 한 스쿱의 바닐라 아이스크림
# Tall(톨) / 355ml (12 fl oz)
# 230
# 10
# 3
# 69
# 18
# 150
# ==== 커피 끝 ====
# 콜드 폼 콜드 브루Cold Foam Cold Brew
# 부드럽고 쫀득하며 달콤한 콜드 폼을 즐기고 콜드 브루를 같이 마시면 더욱 부드러운 목넘김을 즐길 수 있는 음료 입니다.
# Tall(톨) / 355ml (12 fl oz)
# 105
# 0
# 5
# 175
# 20
# 150
# ==== 커피 끝 ====
# 아이스 커피Iced Coffee
# 깔끔하고 상큼함이 특징인 시원한 아이스 커피
# Tall(톨) / 355ml (12 fl oz)
# 5
# 0
# 0
# 10
# 0
# 140
# ==== 커피 끝 ====
# 오늘의 커피Brewed Coffee
# 신선하게 브루드(Brewed)되어 원두의 다양함이 살아있는 커피
# Tall(톨) / 355ml (12 fl oz)
# 5
# 0
# 0
# 10
# 0
# 260
# ==== 커피 끝 ====
# 슈 크림 크런치 라떼Choux Cream Crunch Latte
# 새롭게 돌아온 슈 크림 크런치 라떼!바삭한 슈크런치 토핑이 올라가 진짜 슈 크림 빵을 먹는 느낌을 구현한 새로운 슈 크림 크런치 라떼!
# Tall(톨) / 355ml (12 fl oz)
# 330
# 11
# 9
# 180
# 33
# 63
# ==== 커피 끝 ====
# 아이스 슈 크림 크런치 라떼Iced Choux Cream Crunch Latte
# 새롭게 돌아온 슈 크림 크런치 라떼!바삭한 슈크런치 토핑이 올라가 진짜 슈 크림 빵을 먹는 느낌을 구현한 새로운 슈 크림 크런치 라떼!
# Tall(톨) / 355ml (12 fl oz)
# 275
# 9
# 6
# 130
# 28
# 63
# ==== 커피 끝 ====
# 아이스 헤이즐넛 더블 마키아또Iced Hazelnut Double Macchiato
# 정통 마키아또를 더욱 진하고 색다르게 즐길 수 있는 음료! 에스프레소 투샷의 진한 맛에 헤이즐넛 시럽과 드리즐을 더하고 카라멜 아몬드 토핑까지!마지막은 바리스타의 핸드크래프트 에칭 아트로 마무리한 음료!
# Tall(톨) / 355ml (12 fl oz)
# 240
# 7
# 8
# 115
# 24
# 125
# ==== 커피 끝 ====
# 헤이즐넛 더블 마키아또Hazelnut Double Macchiato
# 정통 마키아또를 더욱 진하고 색다르게 즐길 수 있는 음료! 에스프레소 투샷의 진한 맛에 헤이즐넛 시럽과 드리즐을 더하고 카라멜 아몬드 토핑까지!마지막은 바리스타의 핸드크래프트 에칭 아트로 마무리한 음료!
# Tall(톨) / 355ml (12 fl oz)
# 290
# 7
# 12
# 180
# 30
# 125
# ==== 커피 끝 ====
# 에스프레소 콘 파나Espresso Con Panna
# 에스프레소 샷에 풍부한 휘핑크림을 얹은 강렬하고 달콤한 음료
# Solo(솔로) / 22ml (0.75 fl oz)
# 30
# 1.5
# 0
# 0
# 1
# 75
# ==== 커피 끝 ====
# 에스프레소 마키아또Espresso Macchiato
# 강렬한 에스프레소 위에 소량의 우유 거품이 얹어진 음료
# Solo(솔로) / 22ml (0.75 fl oz)
# 10
# 0
# 1
# 0
# 0
# 75
# ==== 커피 끝 ====
# 아이스 카페 아메리카노Iced Caffe Americano
# 강렬한 에스프레소 샷에 시원한 물의 조화
# Tall(톨) / 355ml (12 fl oz)
# 10
# 0
# 1
# 5
# 0
# 150
# ==== 커피 끝 ====
# 카페 아메리카노Caffe Americano
# 강렬한 에스프레소 샷에 뜨거운 물의 조화
# Tall(톨) / 355ml (12 fl oz)
# 10
# 0
# 1
# 5
# 0
# 150
# ==== 커피 끝 ====
# 아이스 카라멜 마키아또Iced Caramel Macchiato
# 바닐라 시럽, 시원한 우유에 얼음과 에스프레소 샷, 카라멜 드리즐이 어우러진 음료
# Tall(톨) / 355ml (12 fl oz)
# 190
# 4.5
# 7
# 95
# 22
# 75
# ==== 커피 끝 ====
# 카라멜 마키아또Caramel Macchiato
# 바닐라 시럽과 우유, 그리고 그 위에 얹어진 에스프레소 샷과 달콤한 카라멜 드리즐의 조화
# Tall(톨) / 355ml (12 fl oz)
# 200
# 4.5
# 8
# 100
# 22
# 75
# ==== 커피 끝 ====
# 아이스 카푸치노Iced Cappuccino
# 에스프레소 샷과 시원한 우유에 부드러운 우유 거품이 얹어진 시원한 음료.
# Tall(톨) / 355ml (12 fl oz)
# 115
# 3.5
# 6
# 90
# 9
# 75
# ==== 커피 끝 ====
# 카푸치노Cappuccino
# 벨벳같은 우유 거품과 에스프레소 샷의 절묘한 조화!
# Tall(톨) / 355ml (12 fl oz)
# 110
# 3
# 6
# 70
# 8
# 75
# ==== 커피 끝 ====
# 콜드 폼 카푸치노Cold Foam Cappuccino
# 카푸치노 특유의 풍성한 폼을 플레인 콜드 폼으로 표현하였으며, 추로스 슈거 토핑으로 비쥬얼적으로 새로움을 전합니다.
# Tall(톨) / 355ml (12 fl oz)
# 155
# 2
# 5
# 138
# 20
# 150
# ==== 커피 끝 ====
# 라벤더 카페 브레베Lavender Cafe Breve
# [더종로R,청담스타R,한강진역R,홍대입구역사거리R 전용음료] 블랙이글로 추출한 리저브 에스프레소 샷과 은은한 라벤더향이 고급스럽게 어우러진 리저브 특화음료입니다.
# Tall(톨) / 355ml (12 fl oz)
# 406
# 22
# 7
# 140
# 30
# 75
# ==== 커피 끝 ====
# 럼 샷 코르타도Rum Shot Cortado
# [더종로R,청담스타R,한강진역R,홍대입구역사거리R 전용음료] 최고의 리저브 에스프레소 샷, 스팀 밀크 그리고 럼이 짙게 어우러진 스타벅스 리저브 만의 코르타도입니다.
# Short(숏) / 237ml (8 fl oz)
# 70
# 1.8
# 3
# 45
# 8
# 75
# ==== 커피 끝 ====
# 스타벅스 돌체 라떼Starbucks Dolce Latte
# 깊은 에스프레소와 깔끔한 무지방 우유가 어우러진 달콤한 음료.
# Tall(톨) / 355ml (12 fl oz)
# 255
# 2.5
# 12
# 190
# 39
# 150
# ==== 커피 끝 ====
# 아이스 라벤더 카페 브레베Iced Lavender Cafe Breve
# [더종로R,청담스타R,한강진역R,홍대입구역사거리R 전용음료] 블랙이글로 추출한 리저브 에스프레소 샷과 은은한 라벤더향이 고급스럽게 어우러진 리저브 특화음료입니다.
# Tall(톨) / 355ml (12 fl oz)
# 335
# 18
# 6
# 110
# 27
# 75
# ==== 커피 끝 ====
# 아이스 스타벅스 돌체 라떼Iced Starbucks Dolce Latte
# 커피 향과 부드러움의 조화가 아주 멋진 아이스 커피 입니다.
# Tall(톨) / 355ml (12 fl oz)
# 230
# 2.5
# 10
# 145
# 35
# 150
# ==== 커피 끝 ====
# 아이스 카페 라떼Iced Caffe Latte
# 에스프레소 샷과 시원한 우유와 얼음으로 고소한 음료.
# Tall(톨) / 355ml (12 fl oz)
# 110
# 3.5
# 6
# 75
# 8
# 75
# ==== 커피 끝 ====
# 카페 라떼Caffe Latte
# 에스프레소 샷과 따뜻한 우유와 거품으로 마무리된 음료.
# Tall(톨) / 355ml (12 fl oz)
# 180
# 5
# 10
# 115
# 13
# 75
# ==== 커피 끝 ====
# 아이스 카페 모카Iced Caffe Mocha
# 모카시럽과 시원한 우유에 휘핑크림이 토핑된 에스프레소 음료.
# Tall(톨) / 355ml (12 fl oz)
# 250
# 8
# 7
# 70
# 21
# 95
# ==== 커피 끝 ====
# 아이스 화이트 초콜릿 모카Iced White Chocolate Mocha
# 화이트 초콜릿과 시원한 우유가 첨가된 에스프레소 음료.
# Tall(톨) / 355ml (12 fl oz)
# 350
# 11
# 8
# 150
# 41
# 75
# ==== 커피 끝 ====
# 카페 모카Caffe Mocha
# 모카시럽과 스팀밀크에 휘핑크림이 토핑된 에스프레소.
# Tall(톨) / 355ml (12 fl oz)
# 290
# 9
# 10
# 105
# 25
# 95
# ==== 커피 끝 ====
# 화이트 초콜릿 모카White Chocolate Mocha
# 화이트 초콜릿과 스팀밀크가 첨가된 에스프레소 음료.
# Tall(톨) / 355ml (12 fl oz)
# 390
# 11
# 12
# 190
# 45
# 75
# ==== 커피 끝 ====
# 리스트레토 비안코Ristretto Bianco
# 스타벅스 에스프레소 원두의 깊고 진한 풍미를 지닌 리스트레토 샷에 벨벳과 같이 고운 거품의 우유가 어우러져 풍부함과 부드러움을 동시에 느낄 수 있는 음료.
# Tall(톨) / 355ml (12 fl oz)
# 190
# 6
# 10
# 143
# 14
# 130
# ==== 커피 끝 ====
# 바닐라 스타벅스 더블 샷Vanilla Starbucks Double Shot
# 신선하게 제조된 더블 샷 믹스에 바닐라 시럽을 넣고 에스프레소 샷, 얼음이 어우러져 핸드 쉐이킹한 음료입니다.
# 207ml (7 fl oz)
# 125
# 4.5
# 2
# 30
# 14
# 145
# ==== 커피 끝 ====
# 에스프레소Espresso
# 스타벅스의 핵심인 강렬하고 카라멜향이 달콤한 음료
# Solo(솔로) / 22ml (0.75 fl oz)
# 5
# 0
# 0
# 0
# 0
# 75
# ==== 커피 끝 ====
# 카라멜 스타벅스 더블 샷Caramel Starbucks Double Shot
# 신선하게 제조된 더블 샷 믹스에 카라멜 시럽을 넣고 에스프레소 샷, 얼음이 어우러져 핸드 쉐이킹한 음료입니다.
# 207ml (7 fl oz)
# 125
# 5
# 3
# 28.5
# 14
# 150
# ==== 커피 끝 ====
# 커피 스타벅스 더블 샷Coffee Starbucks Double Shot
# 신선하게 제조된 더블 샷 믹스에 클래식 시럽을 넣고 에스프레소 샷, 얼음이 어우러져 핸드 쉐이킹한 음료입니다.
# 207ml (7 fl oz)
# 125
# 5
# 3
# 28.5
# 14
# 150
# ==== 커피 끝 ====
# 클래식 아포가토Classic Affogato
# [리저브R 매장 전용음료] 리저브 에스프레소 투 샷이 바닐라 아이스크림과 진하게 어우러진 정통 아포가토
# Tall(톨) / 355ml (12 fl oz)
# 225
# 10
# 3
# 70
# 18
# 0
# ==== 커피 끝 ====
# 헤이즐넛 스타벅스 더블 샷Hazelnut Starbucks Double Shot
# 신선하게 제조된 더블 샷 믹스에 헤이즐넛 시럽을 넣고 에스프레소 샷, 얼음이 어우러져 핸드 쉐이킹한 음료입니다.
# 207ml (7 fl oz)
# 125
# 5
# 3
# 28.5
# 14
# 150
# ==== 커피 끝 ====
# 슈 크림 크런치 프라푸치노Choux Cream Crunch Frappuccino
# 새롭게 돌아온 슈 크림 크런치 프라푸치노!바삭한 슈크런치 토핑이 올라가 진짜 슈 크림 빵을 먹는 느낌을 구현한 새로운 슈 크림 크런치 프라푸치노!커피 없이 즐길 수 있는 슈 크림 크런치 프라푸치노!
# Tall(톨) / 355ml (12 fl oz)
# 315
# 8
# 5
# 200
# 44
# 0
# ==== 커피 끝 ====
# 모카 프라푸치노Mocha Frappuccino
# 초콜릿, 커피와 얼음이 갈린 음료에 휘핑크림이 토핑된 음료.라이트 프라푸치노용 시럽 선택 가능-Tall 사이즈 기준, 25% 이상 줄어든 저당(Low Sugar)으로 즐기실 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 280
# 6
# 5
# 180
# 36
# 90
# ==== 커피 끝 ====
# 에스프레소 프라푸치노Espresso Frappuccino
# 에스프레소의 강렬함과 약간의 단맛을 시원하게 즐기는 프라푸치노.라이트 프라푸치노용 시럽 선택 가능-Tall 사이즈 기준, 25% 이상 줄어든 저당(Low Sugar)으로 즐기실 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 140
# 1
# 3
# 125
# 22
# 120
# ==== 커피 끝 ====
# 자바 칩 프라푸치노Java Chip Frappuccino
# 커피 프라푸치노에 초콜릿, 초콜릿 칩이 첨가된 아이스 블렌드로 달콤 아삭한 음료.라이트 프라푸치노용 시럽 선택 가능-Tall 사이즈 기준, 25% 이상 줄어든 저당(Low Sugar)으로 즐기실 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 340
# 9
# 6
# 180
# 42
# 100
# ==== 커피 끝 ====
# 카라멜 프라푸치노Caramel Frappuccino
# 카라멜 시럽이 더해진 커피 프라푸치노에 휘핑 크림, 카라멜이 장식된 음료.라이트 프라푸치노용 시럽 선택 가능-Tall 사이즈 기준, 25% 이상 줄어든 저당(Low Sugar)으로 즐기실 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 300
# 7
# 4
# 190
# 39
# 85
# ==== 커피 끝 ====
# 화이트 초콜릿 모카 프라푸치노White Chocolate Mocha Frappuccino
# 화이트 초콜릿, 커피와 우유가 조합된 아이스 블렌드로 휘핑크림이 토핑된 음료.라이트 프라푸치노용 시럽 선택 가능-Tall 사이즈 기준, 25% 이상 줄어든 저당(Low Sugar)으로 즐기실 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 320
# 7
# 5
# 210
# 43
# 85
# ==== 커피 끝 ====
# 그린 티 크림 프라푸치노Green Tea Cream Frappuccino
# 약간의 시럽과 우유와 얼음, 쌉싸름한 녹차가 블렌딩 되어 휘핑크림이 토핑된 음료.라이트 프라푸치노용 시럽 선택 가능-Tall 사이즈 기준, 25% 이상 줄어든 저당(Low Sugar)으로 즐기실 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 290
# 7.5
# 5
# 175
# 42
# 95
# ==== 커피 끝 ====
# 딸기 크림 프라푸치노Strawberries & Cream Frappuccino
# 딸기와 우유의 아이스 블렌드로 휘핑크림과 함께 즐길 수 있는 프라푸치노.라이트 프라푸치노용 시럽 선택 가능-Tall 사이즈 기준, 25% 이상 줄어든 저당(Low Sugar)으로 즐기실 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 360
# 6
# 9
# 310
# 46
# 0
# ==== 커피 끝 ====
# 바닐라 크림 프라푸치노Vanilla Cream Frappuccino
# 우유에 바닐라향이 조합된 아이스 블렌드로 휘핑크림이 토핑된 음료.라이트 프라푸치노용 시럽 선택 가능-Tall 사이즈 기준, 25% 이상 줄어든 저당(Low Sugar)으로 즐기실 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 310
# 5.3
# 9
# 241
# 38
# 0
# ==== 커피 끝 ====
# 제주 까망 크림 프라푸치노Jeju Black Sesame Cream Frappuccino
# [제주지역 한정음료] 제주 까망 라떼의 프라푸치노 버전으로쫄깃한 국내산 흑임자 떡과 블랙 소보로 토핑으로컵빙수처럼 먹는 음료. 고소한 국내산 흑임자와쫄깃한 국내산 흑임자 떡, 달콤한 블랙 소보로 토핑으로제주의 돌 하르방 길을 느껴보세요.
# Grande(그란데) / 473ml (16 fl oz)
# 600
# 7
# 9
# 330
# 79
# 0
# ==== 커피 끝 ====
# 제주 말차샷 크림 프라푸치노Jeju Matcha Shot Cream Frappuccino
# [제주지역 한정음료] 제주 녹차의 풍미가 더욱 진해진 제주 버전의 말차 크림 프라푸치노를 즐겨보세요! 달콤한 연유와 쌉싸름한 녹차가 만나 부드럽고 깔끔한 맛을 동시에 느낄 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 265
# 4.1
# 6
# 180.4
# 43
# 67.1
# ==== 커피 끝 ====
# 제주 쑥떡 크림 프라푸치노Jeju Mugwort Cream Frappuccino
# [제주지역 한정음료] 제주 쑥쑥 라떼의 시원한 버전으로쫄깃쫄깃한 국내산 흑임자 떡으로씹는 재미를 즐길 수 있는 음료.제주 쑥과 국내산 흑임자 떡으로 제주 오름길을 느껴보세요.
# Grande(그란데) / 473ml (16 fl oz)
# 460
# 10
# 8
# 250
# 57
# 0
# ==== 커피 끝 ====
# 제주 호지샷 크림 프라푸치노Jeju Hoji Shot Cream Frappuccino
# [제주지역 한정음료] 100% 제주 호지차 파우더를 사용하여 구수한 호지차의 매력이 돋보이는 제주 버전의 호지샷 크림 프라푸치노를 즐겨보세요! 달콤한 연유와 호지차의 구수한 풍미를 느낄 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 280
# 4.4
# 7
# 186.1
# 46
# 81.2
# ==== 커피 끝 ====
# 초콜릿 크림 칩 프라푸치노Chocolate Cream Chip Frappuccino
# 모카시럽과 자바칩이 혼합된 크림 프라푸치노로 휘핑크림, 초콜렛 드리즐된 음료.라이트 프라푸치노용 시럽 선택 가능-Tall 사이즈 기준, 25% 이상 줄어든 저당(Low Sugar)으로 즐기실 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 370
# 7.5
# 11
# 266
# 44
# 10
# ==== 커피 끝 ====
# 초콜릿 크림 프라푸치노Chocolate Cream Frappuccino
# 모카시럽이 혼합된 크림 프라푸치노에 휘핑크림, 초콜렛 드리즐로 완성된 음료.라이트 프라푸치노용 시럽 선택 가능-Tall 사이즈 기준, 25% 이상 줄어든 저당(Low Sugar)으로 즐기실 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 325
# 5.5
# 10
# 240
# 39
# 10
# ==== 커피 끝 ====
# 딸기 파인 주스Strawberry Pineapple Juice
# 새콤한 딸기와 달콤한 파인애플이 어우러진 건강하고 신선한 주스 타입의 음료입니다.건강한 아침을 신선한 봄 딸기로 건강하게 시작해 보세요.
# Tall(톨) / 355ml (12 fl oz)
# 155
# 0
# 1
# 0
# 41
# 0
# ==== 커피 끝 ====
# 망고 패션 후르츠 블렌디드Mango Passion Fruit Blended
# 진한 블랙 티에 망고 패션 후르츠 주스가 조합된 아이스 블렌드 음료
# Tall(톨) / 355ml (12 fl oz)
# 120
# 0
# 1
# 70
# 25
# 35
# ==== 커피 끝 ====
# 제주 호두 당근 블렌디드Jeju Walnut Carrot Blended
# [제주지역 한정음료] 제주의 당근 밭을 형상화한 음료로제주 구좌 당근과 고소한 호두, 귀여운 당근 삽 초콜릿과 함께제주의 당근밭을 달콤하게 느껴보세요.
# Tall(톨) / 355ml (12 fl oz)
# 80
# 0.7
# 2
# 0
# 0
# 0
# ==== 커피 끝 ====
# 그린 티 바나나 블렌디드Green Tea Banana Blended
# 진한 그린 티와 신선한 바나나1개가 통째로 들어간 든든한 과일 블렌디드
# Grande(그란데) / 473ml (16 fl oz)
# 295
# 0
# 8
# 55
# 22
# 97
# ==== 커피 끝 ====
# 딸기 요거트 블렌디드Strawberry Yogurt Blended
# 딸기와 요거트의 상큼함이 가득 느껴지는 가벼운 컨셉의 블렌디드 음료입니다.
# Tall(톨) / 355ml (12 fl oz)
# 250
# 0.9
# 8
# 128.4
# 48
# 0
# ==== 커피 끝 ====
# 딸기 피치 블렌디드Strawberry Peach Blended
# 새콤달콤한 딸기와 향긋한 복숭아를 한 번에 즐겨보세요.향긋하고 신선한 과일의 풍미가 입안에서 넘쳐 납니다!
# Tall(톨) / 355ml (12 fl oz)
# 216
# 0
# 1
# 20
# 52
# 0
# ==== 커피 끝 ====
# 망고 바나나 블렌디드Mango Banana Blended
# 인기 음료인 망고 패션후르츠 블렌디드에 신선한 바나나 1개가 통째로 들어간 달콤한 프라푸치노
# Grande(그란데) / 473ml (16 fl oz)
# 270
# 1
# 4
# 110
# 48
# 0
# ==== 커피 끝 ====
# 아보카도 블렌디드Avocado Blended
# 가장 트렌디한 과일인 아보카도를 가장 맛있게 즐기는 방법을 스타벅스에서 찾아보세요!리얼 아보카도를 통째로 즐기는 듯한 비주얼은 보는 재미까지 선사합니다.
# Tall(톨) / 355ml (12 fl oz)
# 410
# 7
# 9
# 185
# 45
# 0
# ==== 커피 끝 ====
# 초콜릿 바나나 블렌디드Chocolate Banana Blended
# 진한 초콜릿과 신선한 바나나 1개가 통째로 들어간 달콤하고 든든한 과일 블렌디드
# Grande(그란데) / 473ml (16 fl oz)
# 460
# 2
# 12
# 50
# 60
# 15
# ==== 커피 끝 ====
# 그린 티 레모네이드 피지오Green Tea Lemonade Starbucks Fizzio™
# 그린 티와 상큼한 레모네이드를 스파클링한 시원하고 청량감 있는 음료입니다.
# Tall(톨) / 355ml (12 fl oz)
# 65
# 0
# 0
# 0.2
# 17
# 35
# ==== 커피 끝 ====
# 블랙 티 레모네이드 피지오Black Tea Lemonade Starbucks Fizzio™
# 블랙 티와 상큼한 레모네이드를 스파클링한 시원하고 청량감 있는 음료입니다.
# Tall(톨) / 355ml (12 fl oz)
# 65
# 0
# 0
# 0.2
# 17
# 35
# ==== 커피 끝 ====
# 쿨 라임 피지오Cool Lime Starbucks Fizzio™
# 그린 빈 추출액이 들어간 라임 베이스에 건조된 라임 슬라이스를 넣고 스파클링한 시원하고 청량감 있는 음료입니다. (카페인이 함유된 탄산음료입니다)
# Tall(톨) / 355ml (12 fl oz)
# 100
# 0
# 0
# 0
# 25
# 60
# ==== 커피 끝 ====
# 패션 탱고 티 레모네이드 피지오Passion Tango Tea Lemonade Starbucks Fizzio™
# 패션 티와 상큼한 레모네이드를 스파클링한 시원하고 청량감 있는 음료입니다.
# Tall(톨) / 355ml (12 fl oz)
# 65
# 0
# 0
# 0.2
# 17
# 0
# ==== 커피 끝 ====
# 핑크 자몽 피지오Pink Grapefruit Starbucks Fizzio™
# 신선하게 착즙한 자몽이 스타벅스 만의 수제 탄산음료로 선보입니다.핑크빛의 생자몽으로 아름다운 비주얼과 신선함을 느껴 보세요.
# Tall(톨) / 355ml (12 fl oz)
# 185
# 0
# 1
# 20
# 43
# 0
# ==== 커피 끝 ====
# CMX 블루베리 블리스CMX Blueberry Bliss
# 그린 루이보스와 블루베리, 블랙커런트, 히비스커스가 환상적인 조화를 이룬 허브티입니다.
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 0
# ==== 커피 끝 ====
# CMX 아이스 블루베리 블리스CMX Iced Blueberry Bliss
# 그린 루이보스와 블루베리, 블랙커런트, 히비스커스가 환상적인 조화를 이룬 허브티입니다.
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 0
# ==== 커피 끝 ====
# SIP 블루베리 블리스SIP Blueberry Bliss
# 그린 루이보스와 블루베리, 블랙커런트, 히비스커스가 환상적인 조화를 이룬 허브티입니다.
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 0
# ==== 커피 끝 ====
# SIP 아이스 블루베리 블리스SIP Iced Blueberry Bliss
# 그린 루이보스와 블루베리, 블랙커런트, 히비스커스가 환상적인 조화를 이룬 허브티입니다.
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 0
# ==== 커피 끝 ====
# 그랜마 애플 블랙 티Grandma Apple Black Tea
# 잉글리쉬 브렉퍼스트 티와 신선한 사과, 시나몬과 레몬의 가벼운 터치가마치 할머니의 비밀 레시피같은 묘한 매력의 그랜마 애플 블랙 티를 소개합니다.오직, 티바나 인스파이어드 매장에서만 만날 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 200
# 0.2
# 1
# 5
# 30
# 45
# ==== 커피 끝 ====
# 딸기 유스베리 티Strawberry Youthberry Tea
# 스타벅스 만의 시그니처 티인 유스베리가 신선한 딸기와 만나 환상적인맛을 느낄 수 있는 티 베리에이션 음료입니다.봄 딸기의 신선함을 티 음료로 즐겨 보세요.
# Grande(그란데) / 473ml (16 fl oz)
# 120
# 0
# 1
# 5
# 28
# 0
# ==== 커피 끝 ====
# 라임 패션 티Lime Passion Tea
# 새콤달콤한 히비스커스와 라임의이국적인 조화가 매력적인 라임 패션 티를 만나보세요!
# Tall(톨) / 355ml (12 fl oz)
# 140
# 0
# 0
# 25
# 35
# 150
# ==== 커피 끝 ====
# 레몬 민트 티Lemon Mint Tea
# 새콤한 레몬과 상쾌한 티바나 민트 티가 어우러진새로운 티 베리에이션 음료를 즐겨보세요!
# Tall(톨) / 355ml (12 fl oz)
# 135
# 0
# 0
# 0
# 34
# 0
# ==== 커피 끝 ====
# 민트 블렌드 티Mint Blend Brewed Tea
# 스피어민트, 페퍼민트, 레몬버베나가 블렌딩된 상쾌한 허브 티 입니다.
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 0
# ==== 커피 끝 ====
# 블루베리 블리스 피크닉 티Blueberry Bliss Picnic Tea
# 라임,블루베리,애플 민트, 로즈마리의 풍미가 은은한 그린 루이보스 티와 완벽히 어우러진 산뜻한 티로 나만의 티 여행을 떠나 보세요.오직, 티바나 인스파이어드 매장에서만 만날 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 100
# 0
# 0
# 20
# 17
# 0
# ==== 커피 끝 ====
# 아이스 그랜마 애플 블랙 티Iced Grandma Apple Black Tea
# 잉글리쉬 브렉퍼스트 티와 신선한 사과, 시나몬과 레몬의 가벼운 터치가마치 할머니의 비밀 레시피같은 묘한 매력의 그랜마 애플 블랙 티를 소개합니다.오직, 티바나 인스파이어드 매장에서만 만날 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 230
# 0.2
# 1
# 5
# 38
# 40
# ==== 커피 끝 ====
# 아이스 라임 패션 티Iced Lime Passion Tea
# 새콤달콤한 히비스커스와 라임의이국적인 조화가 매력적인 라임 패션 티를 만나보세요!
# Tall(톨) / 355ml (12 fl oz)
# 90
# 0
# 0
# 15
# 22
# 93
# ==== 커피 끝 ====
# 아이스 레몬 민트 티Iced Lemon Mint Tea
# 새콤한 레몬과 상쾌한 티바나 민트 티가 어우러진새로운 티 베리에이션 음료를 즐겨보세요!
# Tall(톨) / 355ml (12 fl oz)
# 90
# 0
# 0
# 0
# 22
# 0
# ==== 커피 끝 ====
# 아이스 민트 블렌드 티Iced Mint Blend Brewed Tea
# 스피어민트, 페퍼민트, 레몬버베나가 블렌딩된 상쾌한 허브 티 입니다.(약 5분 정도의 티 추출 시간이 소요됩니다.)
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 0
# ==== 커피 끝 ====
# 아이스 블루베리 블리스 피크닉 티Iced Blueberry Bliss Picnic Tea
# 라임,블루베리,애플 민트, 로즈마리의 풍미가 은은한 그린 루이보스 티와 완벽히 어우러진 산뜻한 티로 나만의 티 여행을 떠나 보세요.오직, 티바나 인스파이어드 매장에서만 만날 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 100
# 0
# 0
# 20
# 17
# 0
# ==== 커피 끝 ====
# 아이스 얼 그레이 티Iced Earl Grey Brewed Tea
# 시원하게 즐기는 뜨거운 물에 우려내 라벤더 향이 특징적인 향긋한 블랙 티(약 5분 정도의 티 추출 시간이 소요됩니다.)
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 60
# ==== 커피 끝 ====
# 아이스 유스베리 티Iced Youthberry™Brewed Tea
# 아사이베리, 히비스커스, 장미 꽃잎의 핑크빛 컬러가 감도는 수색과 베리류의 새콤함을 느낄 수 있는 화이트 티 입니다.
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 20
# ==== 커피 끝 ====
# 아이스 잉글리쉬 브렉퍼스트 티Iced English Breakfast Brewed Tea
# 인도 아삼, 스리랑카 실론, 중국의 홍차가 블렌딩 된 깊고 그윽한 블랙 티 입니다.(약 5분 정도의 티 추출 시간이 소요됩니다.)
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 45
# ==== 커피 끝 ====
# 아이스 제주 유기 녹차Iced Jeju Organic Green Tea
# 우수한 품질의 제주도 산 유기 녹차로만 이루어져 맑은 수색과 신선한 향, 맛이 뛰어난 녹차 입니다.(약 3분 정도의 티 추출 시간이 소요됩니다.)
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 16
# ==== 커피 끝 ====
# 아이스 차이 티Iced Chai Brewed Tea
# 진저, 카르다몸, 이국적인 풍미의 시나몬 등이 블렌딩된 블랙 티 입니다.(약 5분 정도의 티 추출 시간이 소요됩니다.)
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 45
# ==== 커피 끝 ====
# 아이스 캐모마일 블렌드 티Iced Chamomile Blend Brewed Tea
# 캐모마일과 라벤더의 부드러운 꽃향이 어우러진 허브 티 입니다.(약 5분 정도의 티 추출 시간이 소요됩니다.)
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 0
# ==== 커피 끝 ====
# 아이스 히비스커스 블렌드 티Iced Hibiscus Blend Brewed Tea
# 히비스커스, 사과의 풍부한 산미, 레몬그라스 등이 블렌딩된 허브 티 입니다.(약 5분 정도의 티 추출 시간이 소요됩니다.)
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 0
# ==== 커피 끝 ====
# 얼 그레이 티Earl Grey Brewed Tea
# 부드러운 얼 그레이에 라벤더 향이 특징적인 향긋한 블랙 티
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 60
# ==== 커피 끝 ====
# 유스베리 티Youthberry™Brewed Tea
# 아사이베리, 히비스커스, 장미 꽃잎의 핑크빛 컬러가 감도는 수색과 베리류의 새콤함을 느낄 수 있는 화이트 티 입니다.
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 20
# ==== 커피 끝 ====
# 잉글리쉬 브렉퍼스트 티English Breakfast Brewed Tea
# 인도 아삼, 스리랑카 실론, 중국의 홍차가 블렌딩 된 깊고 그윽한 블랙 티 입니다.
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 45
# ==== 커피 끝 ====
# 자몽 허니 블랙 티Grapefruit Honey Black Tea
# 새콤달콤한 자몽과 꿀이 깊고 그윽한 풍미의 스타벅스 티바나의 블랙 티와 만났습니다. 화려한 색감과 톡 쏘는 상큼함이 더해진 스타벅스의 새로운 티 음료입니다.
# Tall(톨) / 355ml (12 fl oz)
# 125
# 0
# 0
# 4.2
# 30
# 40
# ==== 커피 끝 ====
# 제주 유기 녹차Jeju Organic Green Tea
# 우수한 품질의 제주도 산 유기 녹차로만 이루어져 맑은 수색과 신선한 향, 맛이 뛰어난 녹차 입니다.
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 16
# ==== 커피 끝 ====
# 차이 티Chai Brewed Tea
# 진저, 카르다몸, 이국적인 풍미의 시나몬 등이 블렌딩된 블랙 티 입니다.
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 45
# ==== 커피 끝 ====
# 캐모마일 블렌드 티Chamomile Blend Brewed Tea
# 캐모마일과 라벤더의 부드러운 꽃향이 어우러진 허브 티 입니다.
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 0
# ==== 커피 끝 ====
# 티 저니 블루베리 블리스Tea Journey Blueberry Bliss
# 티 본연의 재료가 우린 티, 티 베리에이션 음료 변신하는 과정을 즐길 수 있는 색다른 음료입니다. 그린 루이보스와 블루베리, 블랙커런트 가득한 허브티에 각종 생과일과 허브가 어울어져 더욱 풍부한 맛을 가진 음료와 함께 티 여행을 떠나 보세요.Teavana Inspired Store에서만 판매가 됩니다.사이렌오더가 불가한 품목이오니 주문은 직접 매장 파트너에게 문의해 주세요.(BOGO 쿠폰 사용 불가)
# Venti(벤티) / 591ml (20 fl oz)
# 250
# 0
# 0.1
# 65
# 50
# 0
# ==== 커피 끝 ====
# 히비스커스 블렌드 티Hibiscus Blend Brewed Tea
# 히비스커스, 사과의 풍부한 산미, 레몬그라스 등이 블렌딩된 허브 티 입니다.
# Tall(톨) / 355ml (12 fl oz)
# 0
# 0
# 0
# 0
# 0
# 0
# ==== 커피 끝 ====
# 가드닝 블랙 티Gardening Black Tea
# 티바나 인스파이어드 매장에서만 만날 수 있는 음료입니다.텃밭이나 주말농장에서 식물을 가꾸는 자연체험의 경험을 티바나 음료에서 즐겨보세요.식물에 물을 주듯 티를 담고 쟁기로 얼음 표면을 다지는 행위는 일상에서색다른 행복을 느끼게 합니다.바질과 라임의 풍미가 진한 티바나 블랙 티와 어울려 이국적인 맛을 선사합니다.(BOGO 쿠폰 사용 불가)
# Tall(톨) / 355ml (12 fl oz)
# 140
# 0
# 0
# 1.7
# 29
# 35
# ==== 커피 끝 ====
# 가드닝 캐모마일 티Gardening Chamomile Tea
# 티바나 인스파이어드 매장에서만 만날 수 있는 음료입니다.텃밭이나 주말농장에서 식물을 가꾸는 자연체험의 경험을 티바나 음료에서 즐겨보세요.식물에 물을 주듯 티를 담고 쟁기로 얼음 표면을 다지는 행위는 일상에서색다른 행복을 느끼게 합니다.바질과 라임의 풍미가 티바나 캐모마일 티와 어울려 색다른 향기와 맛을 선사합니다.(BOGO 쿠폰 사용 불가)
# Tall(톨) / 355ml (12 fl oz)
# 130
# 0
# 0
# 2.3
# 30
# 0
# ==== 커피 끝 ====
# 아이스 자몽 허니 블랙 티Iced Grapefruit Honey Black Tea
# 새콤달콤한 자몽과 꿀이 깊고 그윽한 풍미의 스타벅스 티바나의 블랙 티와 만났습니다. 화려한 색감과 톡 쏘는 상큼함이 더해진 스타벅스의 새로운 티 음료입니다.
# Tall(톨) / 355ml (12 fl oz)
# 125
# 0
# 0
# 4.3
# 30
# 35
# ==== 커피 끝 ====
# 얼 그레이 레몬 프로즌 티Earl Grey Lemon Frozen Tea
# 향긋한 베르가못 향의 얼 그레이 티와 상큼한 레몬, 애플민트의 풍미, 알로에베라의 식감이 가득한 새로운 개념의 아이스 티 음료입니다.
# Grande(그란데) / 473ml (16 fl oz)
# 205
# 0
# 1
# 15
# 45
# 15
# ==== 커피 끝 ====
# 프로즌 아이스 그린 티 레모네이드Frozen Iced Green Tea Lemonade
# 완전히 새로운 '티 레모네이드'를 소개합니다.프로즌 아이스 그린 티 레모네이드는 더욱 시원하고 풍부해진 레몬의 풍미와스타벅스 티바나 만의 그린 티의 조화로 상큼함을 느낄 수 있습니다.Icy한 질감의 새로운 아이스 티를 즐겨보세요.
# Tall(톨) / 355ml (12 fl oz)
# 140
# 0
# 0
# 2
# 30
# 35
# ==== 커피 끝 ====
# 프로즌 아이스 블랙 티 레모네이드Frozen Iced Black Tea Lemonade
# 완전히 새로운 '티 레모네이드'를 소개합니다.프로즌 아이스 블랙 티 레모네이드는 더욱 시원하고 풍부해진 레몬의 풍미와스타벅스 티바나 만의 블랙 티의 조화로 상큼함을 느낄 수 있습니다.Icy한 질감의 새로운 아이스 티를 즐겨보세요.
# Tall(톨) / 355ml (12 fl oz)
# 140
# 0
# 0
# 2
# 30
# 35
# ==== 커피 끝 ====
# 프로즌 아이스 패션 탱고 티 레모네이드Frozen Iced Passion Tango Tea Lemonade
# 완전히 새로운 '티 레모네이드'를 소개합니다.프로즌 아이스 패션 탱고 티 레모네이드는 더욱 시원하고 풍부해진 레몬의 풍미와스타벅스 티바나 만의 패션 탱고 티의 조화로 상큼함을 느낄 수 있습니다.Icy한 질감의 새로운 아이스 티를 즐겨보세요.
# Tall(톨) / 355ml (12 fl oz)
# 140
# 0
# 0
# 2
# 30
# 0
# ==== 커피 끝 ====
# 핑크베리 유스베리Pinkberry Youthberry Tea
# 새콤한 유스베리 티에 애플민트와 블루베리가 조화를 이룬 이국적인 달콤함이 가득한 핸드 쉐이킹 아이스 티 입니다.
# Grande(그란데) / 473ml (16 fl oz)
# 85
# 0
# 1
# 25
# 20
# 10
# ==== 커피 끝 ====
# 그린 티 라떼Green Tea Latte
# 쌉싸름한 녹차와 부드러운 스팀우유가 혼합된 밀크 티
# Tall(톨) / 355ml (12 fl oz)
# 260
# 6
# 10
# 170
# 29
# 95
# ==== 커피 끝 ====
# 바닐라 블랙 티 라떼Vanilla Black Tea Latte
# 마이크로 그라운드 블랙 티로 기존보다 풍부하고부드러운 블랙 티 라떼!마이크로 블랙 티 파우더로 더욱 깊은 풍미와 부드러움을 함께 느끼며부담없이 마실 수 있는 티 라떼
# Tall(톨) / 355ml (12 fl oz)
# 255
# 7
# 11
# 170
# 26
# 128
# ==== 커피 끝 ====
# 아이스 그린 티 라떼Iced Green Tea Latte
# 차갑게 즐기는 쌉싸름한 녹차와 부드러운 우유가 조합된 밀크 티
# Tall(톨) / 355ml (12 fl oz)
# 200
# 4
# 7
# 120
# 24
# 95
# ==== 커피 끝 ====
# 아이스 바닐라 블랙 티 라떼Iced Vanilla Black Tea Latte
# 마이크로 그라운드 블랙 티로 기존보다 풍부하고부드러운 블랙 티 라떼!마이크로 블랙 티 파우더로 더욱 깊은 풍미와 부드러움을 함께 느끼며부담없이 마실 수 있는 티 라떼
# Tall(톨) / 355ml (12 fl oz)
# 135
# 3.1
# 5
# 80
# 16
# 128
# ==== 커피 끝 ====
# 아이스 얼 그레이 티 라떼Iced Earl Grey Tea Latte
# 바닐라 시럽이 더해진 향긋한 얼그레이 티에 부드러운 우유가 어우리진 아이스 티 라떼 입니다.(약 5분 정도의 티 추출시간이 소요됩니다.)
# Tall(톨) / 355ml (12 fl oz)
# 60
# 0
# 2
# 30
# 13
# 60
# ==== 커피 끝 ====
# 아이스 제주 호지샷 라떼Iced Jeju Hoji Shot Latte
# [제주지역 한정음료] 100% 제주 호지차 파우더를 사용하여 구수한 호지차의 매력이 돋보이는 제주 버전의 호지샷 라떼를 즐겨보세요! 달콤한 연유와 호지차의 구수한 풍미를 느낄 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 240
# 5.3
# 8
# 122
# 31
# 81.1
# ==== 커피 끝 ====
# 아이스 차이 티 라떼Iced Chai Tea Latte
# 부드러운 우유에 이국적인 스파이시한 풍미가 특징적인 티 라떼 입니다.
# Tall(톨) / 355ml (12 fl oz)
# 190
# 3
# 5
# 70
# 31
# 75
# ==== 커피 끝 ====
# 아이스 체스트넛 블랙 티 라떼Iced Chestnut Black Tea Latte
# 달콤하고 고소한 밤 소스와 함께 더욱 진하고깊은 풍미의 블랙 티 라떼!기존의 맑은 느낌의 티 라떼와 달리 더욱 달콤하고 진하고 깊은 풍미의블랙 티 라떼를 즐겨보세요.
# Tall(톨) / 355ml (12 fl oz)
# 215
# 3.1
# 6
# 85
# 23
# 128
# ==== 커피 끝 ====
# 얼그레이 티 라떼Earl Grey Tea Latte
# 바닐라 시럽이 더해진 향긋한 얼그레이 티에 부드러운 우유가 어우리진 티 라떼 입니다.
# Tall(톨) / 355ml (12 fl oz)
# 100
# 0
# 5
# 100
# 19
# 60
# ==== 커피 끝 ====
# 제주 호지샷 라떼Jeju Hoji Shot Latte
# [제주지역 한정음료] 100% 제주 호지차 파우더를 사용하여 구수한 호지차의 매력이 돋보이는 제주 버전의 호지샷 라떼를 즐겨보세요! 달콤한 연유와 호지차의 구수한 풍미를 느낄 수 있습니다.
# Tall(톨) / 355ml (12 fl oz)
# 330
# 8.1
# 12
# 192.8
# 38
# 81.2
# ==== 커피 끝 ====
# 차이 티 라떼Chai Tea Latte
# 부드러운 우유에 이국적인 스파이시한 풍미가 특징적인 티 라떼 입니다.
# Tall(톨) / 355ml (12 fl oz)
# 200
# 3
# 6
# 70
# 31
# 75
# ==== 커피 끝 ====
# 체스트넛 블랙 티 라떼Chestnut Black Tea Latte
# 달콤하고 고소한 밤 소스와 함께 더욱 진하고깊은 풍미의 블랙 티 라떼!기존의 맑은 느낌의 티 라떼와 달리 더욱 달콤하고 진하고 깊은 풍미의블랙 티 라떼를 즐겨보세요.
# Tall(톨) / 355ml (12 fl oz)
# 330
# 7
# 11
# 180
# 32
# 128
# ==== 커피 끝 ====
# 시그니처 핫 초콜릿Signature Hot Chocolate
# 유럽 스타일의 진한 핫 초콜릿으로 휘핑크림과 코코아 파우더가 토핑된 음료.
# Tall(톨) / 355ml (12 fl oz)
# 435
# 16
# 12
# 114
# 37
# 15
# ==== 커피 끝 ====
# 아이스 시그니처 초콜릿Iced Signature Chocolate
# 진한 초콜릿과 시원한 우유에 휘핑과 코코아 파우더가 얹어진 음료.
# Tall(톨) / 355ml (12 fl oz)
# 435
# 16
# 12
# 114
# 37
# 15
# ==== 커피 끝 ====
# 봄 딸기 라떼Spring Strawberry Latte
# 신선한 딸기의 새콤함과 아가베에서 오는 달콤함이 부드럽게 만난 라떼입니다.봄 딸기의 신선함을 라떼 음료로 즐겨 보세요.
# Grande(그란데) / 473ml (16 fl oz)
# 240
# 4.1
# 6
# 90
# 38
# 0
# ==== 커피 끝 ====
# 스팀 우유Steamed Milk
# 부드럽고 담백한 따뜻한 우유.
# Tall(톨) / 355ml (12 fl oz)
# 215
# 7
# 13
# 173
# 18
# 0
# ==== 커피 끝 ====
# 아이스 라임 플로터Iced Lime Floater
# [더종로R,청담스타R,한강진역R,홍대입구역사거리R 전용음료] 라임, 민트 그리고 리저브 콜드 브루 샷으로 스타벅스 리저브만의 색깔로 변주한 모히토 음료입니다.
# Grande(그란데) / 473ml (16 fl oz)
# 110
# 0
# 0.3
# 6.5
# 27
# 7
# ==== 커피 끝 ====
# 아이스 오렌지 플로터Iced Orange Floater
# [더종로R,청담스타R,한강진역R,홍대입구역사거리R 전용음료] 오렌지의 상큼함과 리저브 콜드 브루 샷이 상쾌하게 느껴지는 리프레쉬 음료입니다.
# Grande(그란데) / 473ml (16 fl oz)
# 100
# 0
# 0.6
# 7
# 22
# 7
# ==== 커피 끝 ====
# 아이스 와일드 베리 플로터Iced Wild Berry Floater
# [더종로R,청담스타R,한강진역R,홍대입구역사거리R 전용음료] 블랙베리, 딸기, 스파이스 그리고 리저브 콜드 브루 샷이 어우러진 리프레쉬 음료입니다.
# Grande(그란데) / 473ml (16 fl oz)
# 130
# 0
# 1
# 9
# 28
# 7
# ==== 커피 끝 ====
# 아이스 제주 까망 라떼Iced Jeju Black Sesame Latte
# [제주지역 한정음료] 제주도의 돌담길과 하르방의 풍경을 제주 까망 라떼로 느껴보세요.고소한 흑임자와 달콤한 소보로 토핑으로 시원하게 누구나 즐길 수 있는 음료입니다.
# Grande(그란데) / 473ml (16 fl oz)
# 225
# 11
# 8
# 130
# 13
# 0
# ==== 커피 끝 ====
# 우유Milk
# 고소하고 담백한 신선한 우유.
# Tall(톨) / 355ml (12 fl oz)
# 240
# 8
# 12
# 200
# 18
# 0
# ==== 커피 끝 ====
# 제주 까망 라떼Jeju Black Sesame Latte
# [제주지역 한정음료] 제주도의 돌담길과 하르방의 풍경을 제주 까망 라떼로 느껴보세요.고소한 흑임자와 달콤한 소보로 토핑으로 누구나 즐길 수 있는 음료입니다.
# Grande(그란데) / 473ml (16 fl oz)
# 225
# 7
# 10
# 170
# 18
# 0
# ==== 커피 끝 ====
# 제주 쑥쑥 라떼Jeju Mugwort Latte
# [제주지역 한정음료] 제주의 푸릇푸릇한 쑥 향을 느끼며 건강과힐링을 즐기는 음료로 제주의 오름길을 상징하는 음료.제주 쑥으로 향긋하고 푸릇푸릇한 쑥 향을 느끼며건강과 힐링을 느낄 수 있는 Non Coffee음료.
# Grande(그란데) / 473ml (16 fl oz)
# 425
# 9
# 16
# 210
# 50
# 0
# ==== 커피 끝 ====
# 제주 에메랄드 레모네이드Jeju Emerald Lemonade
# [제주지역 한정음료] 제주 해녀가 느끼는 깊은 바닷속 시원한 길의제주 바다를 상징하는 음료. 천연색소인 스피룰리나를 이용한달콤한 블루 파인 베이스와 상큼한 레모네이드로깊고 아름다운 제주 바닷길을 느껴보세요.
# Grande(그란데) / 473ml (16 fl oz)
# 195
# 0
# 0
# 15
# 46
# 0
# ==== 커피 끝 ====
# 레몬톡스 주스 270ML
# 상큼한 레몬과 카옌 페퍼의 스파이시함을 그대로 느낄 수 있는 주스
# 270 ml
# 140
# 0
# 1
# 22
# 30
# 0
# ==== 커피 끝 ====
# 베리브리즈 주스 270MLBerry Breeze Jucie 270ML
# 상큼한 복분자와 새콤달콤 블루베리와 비트로 나에게 활력을 주는 주스
# 270 ml
# 140
# 0
# 1
# 5
# 29
# 0
# ==== 커피 끝 ====
# 스윗캐럿 주스270MLSweet Carrot Juice 270ML
# 상큼한 오렌지와 부드러운 당근의 조화로 달콤한 채소과일 주스
# 270 ml
# 120
# 0
# 1
# 10
# 25
# 0
# ==== 커피 끝 ====
# 클린그린 주스 270ML
# 녹색 채소의 신선함을 그대로 담은 주스
# 270 ml
# 125
# 0
# 2
# 19
# 27
# 0
# ==== 커피 끝 ====
# 딸기주스 190ML
# 국내산 딸기가 듬뿍 들어간 달콤한 과일 주스
# 190 ml
# 100
# 0
# 1
# 15
# 19
# 0
# ==== 커피 끝 ====
# 망고주스 190ML
# 열대 과일 망고가 듬뿍 들어간 달콤한 과일주스
# 190 ml
# 112
# 0
# 1
# 35
# 24
# 0
# ==== 커피 끝 ====
# 케일&사과주스 190ML
# 국내산 케일과 달콤한 사과를 그대로 담은 주스
# 190 ml
# 135
# 0
# 2
# 20
# 26
# 0
# ==== 커피 끝 ====
# 토마토주스 190ML
# 국내산 토마토의 생생함이 그대로 담겨 있는 주스
# 190 ml
# 70
# 0
# 1
# 120
# 17
# 0
# ==== 커피 끝 ====
# 패션프루츠 주스 190MLPassion Fruit Juice190ML
# 여신의 과일의 패션프루츠로 상큼한 비타민 가득한 과일주스패션프루츠로 오늘도 예쁨 한 잔.
# 190 ml
# 104
# 0
# 0.9
# 5
# 21
# 0
# ==== 커피 끝 ====
# 한라봉주스 190ML
# 제주 한라봉의 풍미와 달콤함을 그대로 담은 과일주스
# 190 ml
# 88
# 0
# 1
# 40
# 20
# 0
# ==== 커피 끝 ====
# 햇사과주스 No.2 190MLNewly Harvested Apple Juice No.2 190ML
# 사과 한 개 반을 껍질 그대로 착즙한 햇사과 주스 2탄.상큼한 햇사과 주스로 상쾌한 하루를 즐겨보세요~!
# 190 ml
# 113
# 0
# 0.2
# 5
# 22
# 0
# ==== 커피 끝 ====
# 블루베리 요거트 190ML
# 블루베리 과육과 살아 있는 유산균
# 190 ml
# 155
# 3.6
# 5
# 70
# 18
# 0
# ==== 커피 끝 ====
# 우리유자 요거트 190MLWoori Yuzu Yogurt 190ML
# 국내산 우리유자의 상큼함을 듬뿍 담은 마시는 요거트
# 190 ml
# 180
# 3.4
# 4
# 45
# 25
# 0
# ==== 커피 끝 ====
# 치아씨드 요거트 190ML
# 톡톡 터지는 치아씨드와 살아 있는 유산균
# 190 ml
# 145
# 3.9
# 6
# 70
# 14
# 0
# ==== 커피 끝 ====
