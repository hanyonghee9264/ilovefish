# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Chrome('/Users/han-yonghee/projects/coffeecalorie/.tool/chromedriver_76')

driver.get('https://www.twosome.co.kr:7009/menu/list.asp?rank=2')
html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

# %%
# 카테고리명
category_names = soup.select('div#content > ul.tab > li:nth-of-type(n+2)')

# 카테고리명 뽑기
for category in category_names:
    category_name = category.get_text(strip=True)
    print(category_name)

# 카테고리 4개 주소 [에스프레소, 블렌디드, 티, 기타]
category_pages_base_url = 'https://www.twosome.co.kr:7009/menu/list.asp?rank=2&c_prt_cate_idx='
category_pages_url = ['76', '213', '214', '331']

# 카테고리별 페이지 접근
for num in category_pages_url:
    driver.get(category_pages_base_url + num)

# %%
category_pages_base_url = 'https://www.twosome.co.kr:7009/menu/list.asp?rank=2&c_prt_cate_idx='
category_pages_url = ['76', '213', '214', '331']

# 카테고리별 페이지 접근
for num in category_pages_url:
    driver.get(category_pages_base_url + num)
    # Category Content
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    div_content = soup.select('div#content > div.product-container > ul.product-list li')
    for content in div_content:
        coffee_detail_page_base_url = 'https://www.twosome.co.kr:7009/menu/'
        coffee_detail_page_url = content.select_one('p > a').get('href')
        driver.get(coffee_detail_page_base_url+coffee_detail_page_url)
        
        html = driver.page_source
        soup = BeautifulSoup(html, 'lxml')
        # 커피 디테일 페이지
        detail_page_content = soup.select('div#content > div.line-box > div.product-view')

        # 커피 디테일 페이지 [성분표]
        for detail in detail_page_content:
            # 커피 이미지
            coffee_img_base_url = 'https://www.twosome.co.kr:7009/'
            coffee_img = detail.select_one('div.thumb > div#imgView > img').get('src')
            coffee_image = coffee_img_base_url + coffee_img
            # 커피 이름
            coffee_name = detail.select_one('div.product-des > p.tit02').get_text(strip=True)
            print(coffee_name)
            # 커피 설명
            coffee_infos = detail.select_one('p.des').get_text(strip=True)
            # 커피 디테일 페이지 [성분표]
            coffee_table = detail.select_one('dl.nutrition > dd > ul')
            # 커피 사이즈
            coffee_size = coffee_table.select_one('li.total-g > span').get_text(strip=True)
            # 커피 칼로리
            coffee_calorie = coffee_table.select_one('li:nth-of-type(3) > span').get_text(strip=True)
            # 커피 포화지방
            coffee_fats = coffee_table.select_one('li:nth-of-type(6) > span').get_text(strip=True)
            # 커피 단백질
            coffee_protein = coffee_table.select_one('li:nth-of-type(5) > span').get_text(strip=True)
            # 커피 나트륨
            coffee_sodium = coffee_table.select_one('li:nth-of-type(7) > span').get_text(strip=True)
            # 커피 당류
            coffee_sugar = coffee_table.select_one('li:nth-of-type(4) > span').get_text(strip=True)
# Out:
# 아보카도 콜드브루 프라페
# 코코넛 콜드브루 프라페
# 흑당 라떼
# 스페니쉬 연유 라떼
# 아이스 스페니쉬 연유 라떼
# 롱블랙
# 아이스 롱블랙
# 아이스 숏라떼
# 카라멜 마키아또
# 카페 아메리카노
# 카푸치노
# 에스프레소 마키아또 더블
# 아이스 바닐라 라떼
# 에스프레소 마키아또 싱글
# 카페 모카
# 아이스 커피
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-2e9fd56735b6> in <module>
#      39             coffee_fats = coffee_table.select_one('li:nth-of-type(6) > span').get_text(strip=True)
#      40             # 커피 단백질
# ---> 41             coffee_protein = coffee_table.select_one('li:nth-of-type(5) > span').get_text(strip=True)
#      42             # 커피 나트륨
#      43             coffee_sodium = coffee_table.select_one('li:nth-of-type(7) > span').get_text(strip=True)
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/bs4/element.py in select_one(self, selector, namespaces, **kwargs)
#    1342     def select_one(self, selector, namespaces=None, **kwargs):
#    1343         """Perform a CSS selection operation on the current element."""
# -> 1344         value = self.select(selector, namespaces, 1, **kwargs)
#    1345         if value:
#    1346             return value[0]
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/bs4/element.py in select(self, selector, namespaces, limit, **kwargs)
#    1374             )
#    1375
# -> 1376         return soupsieve.select(selector, self, namespaces, limit, **kwargs)
#    1377
#    1378     # Old names for backwards compatibility
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/soupsieve/__init__.py in select(select, tag, namespaces, limit, flags, **kwargs)
#     110     """Select the specified tags."""
#     111
# --> 112     return compile(select, namespaces, flags, **kwargs).select(tag, limit)
#     113
#     114
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/soupsieve/css_match.py in select(self, tag, limit)
#    1311         """Select the specified tags."""
#    1312
# -> 1313         return list(self.iselect(tag, limit))
#    1314
#    1315     def iselect(self, tag, limit=0):
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/soupsieve/css_match.py in iselect(self, tag, limit)
#    1316         """Iterate the specified tags."""
#    1317
# -> 1318         for el in CSSMatch(self.selectors, tag, self.namespaces, self.flags).select(limit):
#    1319             yield el
#    1320
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/soupsieve/css_match.py in select(self, limit)
#    1194
#    1195         for child in self.get_descendants(self.tag):
# -> 1196             if self.match(child):
#    1197                 yield child
#    1198                 if limit is not None:
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/soupsieve/css_match.py in match(self, el)
#    1221         """Match."""
#    1222
# -> 1223         return not self.is_doc(el) and self.is_tag(el) and self.match_selectors(el, self.selectors)
#    1224
#    1225
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/soupsieve/css_match.py in match_selectors(self, el, selectors)
#    1123
#    1124         match = False
# -> 1125         is_not = selectors.is_not
#    1126         is_html = selectors.is_html
#    1127         if not (is_html and (self.is_xml and not self.html_namespace)):
#
# KeyboardInterrupt:

# %%
# 카테고리명
category_names = soup.select('div#content > ul.tab > li:nth-of-type(n+2)')
    
category_pages_base_url = 'https://www.twosome.co.kr:7009/menu/list.asp?rank=2&c_prt_cate_idx='
category_pages_url = ['76', '213', '214', '331']

# 카테고리별 페이지 접근
for a,b in zip(category_names,category_pages_url):
    category_name = a.get_text(strip=True)
    print(category_name)
    driver.get(category_pages_base_url + num)
    # Category Content
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    div_content = soup.select('div#content > div.product-container > ul.product-list li')
    for content in div_content:
        coffee_detail_page_base_url = 'https://www.twosome.co.kr:7009/menu/'
        coffee_detail_page_url = content.select_one('p > a').get('href')
        driver.get(coffee_detail_page_base_url+coffee_detail_page_url)
        
        html = driver.page_source
        soup = BeautifulSoup(html, 'lxml')
        # 커피 디테일 페이지
        detail_page_content = soup.select('div#content > div.line-box > div.product-view')

        # 커피 디테일 페이지 [성분표]
        for detail in detail_page_content:
            # 커피 이미지
            coffee_img_base_url = 'https://www.twosome.co.kr:7009/'
            coffee_img = detail.select_one('div.thumb > div#imgView > img').get('src')
            coffee_image = coffee_img_base_url + coffee_img
            # 커피 이름
            coffee_name = detail.select_one('div.product-des > p.tit02').get_text(strip=True)
            print(coffee_name)
            # 커피 설명
            coffee_infos = detail.select_one('p.des').get_text(strip=True)
            # 커피 디테일 페이지 [성분표]
            coffee_table = detail.select_one('dl.nutrition > dd > ul')
            # 커피 사이즈
            coffee_size = coffee_table.select_one('li.total-g > span').get_text(strip=True)
            # 커피 칼로리
            coffee_calorie = coffee_table.select_one('li:nth-of-type(3) > span').get_text(strip=True)
            # 커피 포화지방
            coffee_fats = coffee_table.select_one('li:nth-of-type(6) > span').get_text(strip=True)
            # 커피 단백질
            coffee_protein = coffee_table.select_one('li:nth-of-type(5) > span').get_text(strip=True)
            # 커피 나트륨
            coffee_sodium = coffee_table.select_one('li:nth-of-type(7) > span').get_text(strip=True)
            # 커피 당류
            coffee_sugar = coffee_table.select_one('li:nth-of-type(4) > span').get_text(strip=True)
# Out:
# 에스프레소
# 아보카도 콜드브루 프라페
# 코코넛 콜드브루 프라페
# 흑당 라떼
# 스페니쉬 연유 라떼
# 아이스 스페니쉬 연유 라떼
# 롱블랙
# 아이스 롱블랙
# 아이스 숏라떼
# 카라멜 마키아또
# 카페 아메리카노
# 카푸치노
# 에스프레소 마키아또 더블
# 아이스 바닐라 라떼
# 에스프레소 마키아또 싱글
# 카페 모카
# 아이스 커피
# 아이스 카페 라떼
# 에스프레소 콘 파나 더블
# 콜드브루
# 아이스 카페 아메리카노
# 카페 라떼
# 콜드브루 라떼
# 아이스 카페 모카
# 티라미수 라떼
# 에스프레소 콘 파나 싱글
# 시그니처 라떼
# 바닐라 라떼
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e545fb58d956> in <module>
#      17         coffee_detail_page_base_url = 'https://www.twosome.co.kr:7009/menu/'
#      18         coffee_detail_page_url = content.select_one('p > a').get('href')
# ---> 19         driver.get(coffee_detail_page_base_url+coffee_detail_page_url)
#      20
#      21         html = driver.page_source
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     321             response = conn.urlopen(method, url, **kw)
#     322         else:
# --> 323             response = conn.urlopen(method, u.request_uri, **kw)
#     324
#     325         redirect_location = redirect and response.get_redirect_location()
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/var/pyenv/versions/coffee-calorie/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/local/var/pyenv/versions/3.6.7/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /usr/local/var/pyenv/versions/3.6.7/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/local/var/pyenv/versions/3.6.7/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/local/var/pyenv/versions/3.6.7/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:
